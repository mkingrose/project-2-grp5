# %%
import pandas as pd

# %%
df = pd.read_csv ("/Users/jdwhite/SecondProject2/merged.csv")

# %%
df.to_html ("data.html", index = False)

# %%
table = df.to_html()

# %%
print(table)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Country_Code</th>
#       <th>Country</th>
#       <th>Year</th>
#       <th>Start_Date</th>
#       <th>Event_Name</th>
#       <th>Hazard_Category</th>
#       <th>Hazard_Type</th>
#       <th>New_Displacements</th>
#       <th>Country_2D</th>
#       <th>Continent</th>
#       <th>Population</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AGO</td>
#       <td>Angola</td>
#       <td>2013</td>
#       <td>3/20/2013</td>
#       <td>Luanda floods</td>
#       <td>Weather related</td>
#       <td>Flood</td>
#       <td>2450.0</td>
#       <td>AO</td>
#       <td>AF</td>
#       <td>26015780</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AGO</td>
#       <td>Angola</td>
#       <td>2015</td>
#       <td>3/28/2015</td>
#       <td>Cuanza Sul flood</td>
#       <td>Weather related</td>
#       <td>Flood</td>
# ...
