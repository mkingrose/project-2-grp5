# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
csv_path = "Resources/merged.csv"

merged_df = pd.read_csv(csv_path)

merged_df.head()
# Out:
#   Country_Code Country  Year Start_Date           Event_Name  Hazard_Category  \
# 0          AGO  Angola  2013  3/20/2013        Luanda floods  Weather related
# 1          AGO  Angola  2015  3/28/2015     Cuanza Sul flood  Weather related
# 2          AGO  Angola  2015   3/9/2015  Luanda flash floods  Weather related
# 3          AGO  Angola  2015  3/11/2015   Lobito flash flood  Weather related
# 4          AGO  Angola  2016   1/1/2016  Rainy season floods  Weather related
#
#   Hazard_Type  New_Displacements Country_2D Continent  Population
# 0       Flood             2450.0         AO        AF    26015780
# 1       Flood              483.0         AO        AF    27884381
# 2       Flood             3920.0         AO        AF    27884381
# 3       Flood             1192.0         AO        AF    27884381
# 4       Flood            19103.0         AO        AF    28842484

# %%
hazard_counts = merged_df["Hazard_Type"].value_counts()
hazard_counts
# Out:
# Flood                  485
# Storm                  210
# Wet mass movement       41
# Wildfire                29
# Drought                 12
# Earthquake              10
# Dry mass movement        5
# Volcanic activity        1
# Extreme temperature      1
# Volcanic eruption        1
# Name: Hazard_Type, dtype: int64

# %%
grouped_hazard_df = merged_df.groupby(['Hazard_Type'])

grouped_hazard_df.count().head(10)
# Out:
#                      Country_Code  Country  Year  Start_Date  Event_Name  \
# Hazard_Type
# Drought                        12       12    12          12          12
# Dry mass movement               5        5     5           5           5
# Earthquake                     10       10    10          10          10
# Extreme temperature             1        1     1           1           1
# Flood                         485      485   485         485         485
# Storm                         210      210   210         210         210
# Volcanic activity               1        1     1           1           1
# Volcanic eruption               1        1     1           1           1
# Wet mass movement              41       41    41          41          41
# Wildfire                       29       29    29          29          29
#
#                      Hazard_Category  New_Displacements  Country_2D  \
# Hazard_Type
# Drought                           12                 12          12
# Dry mass movement                  5                  5           5
# Earthquake                        10                 10          10
# Extreme temperature                1                  1           1
# Flood                            485                485         476
# Storm                            210                210         208
# Volcanic activity                  1                  1           1
# Volcanic eruption                  1                  1           1
# Wet mass movement                 41                 41          41
# Wildfire                          29                 29          29
#
#                      Continent  Population
# Hazard_Type
# Drought                     12          12
# Dry mass movement            5           5
# Earthquake                  10          10
# Extreme temperature          1           1
# Flood                      485         485
# Storm                      210         210
# Volcanic activity            1           1
# Volcanic eruption            1           1
# Wet mass movement           41          41
# Wildfire                    29          29

# %%
displaced_total = grouped_hazard_df["New_Displacements"].sum()
displaced_total
# Out:
# Hazard_Type
# Drought                1846511.0
# Dry mass movement         9954.0
# Earthquake               19727.0
# Extreme temperature       1425.0
# Flood                  8620983.0
# Storm                  1652915.0
# Volcanic activity         3900.0
# Volcanic eruption         2500.0
# Wet mass movement        26210.0
# Wildfire                 39230.0
# Name: New_Displacements, dtype: float64

# %%
# Creating a new DataFrame using both duration and count
hazard_summary_df = pd.DataFrame({"Instances of Hazard": hazard_counts,
                                    "Total New Displacements": displaced_total})
hazard_summary_df.head()
# Out:
#                      Instances of Hazard  Total New Displacements
# Drought                               12                1846511.0
# Dry mass movement                      5                   9954.0
# Earthquake                            10                  19727.0
# Extreme temperature                    1                   1425.0
# Flood                                485                8620983.0

# %%
# x_axis = np.arange(len(displaced_total)
# tick_location = [value for value in x_axis]
# Out:
#   File "<ipython-input-9-44dc74fb1dab>", line 2
#     tick_location = [value for value in x_axis]
#                 ^
# SyntaxError: invalid syntax

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Hazards = ["Drought", "Dry mass movement", "Earthquake", "Extreme temperature", "Flood", "Storm", "Volcanic activity", "Volcanic Eruption", "Wet mass movement", "Wildfire"]
Data = hazard_summary_df["Total New Displacements"]
ax.bar(Hazards,Data, color = "darkcyan")
plt.xticks(rotation=90)
plt.xlabel("Types of Hazards")
plt.ylabel("10-year Total New Displacements")
plt.savefig("out.png",bbox_inches='tight')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
Hazards = ["Drought", "Dry mass movement", "Earthquake", "Extreme temperature", "Flood", "Storm", "Volcanic activity", "Volcanic Eruption", "Wet mass movement", "Wildfire"]
Data = hazard_summary_df["Instances of Hazard"]
ax.bar(Hazards,Data)
plt.xticks(rotation=90)
plt.xlabel("Types of Hazards")
plt.ylabel("10-year Total Hazard Instances")
plt.show()
plt.savefig("image.png")
